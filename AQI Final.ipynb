# %% [markdown]
# ## AIR QUALITY INDEX
#
# #### The air quality index (AQI) is an index for reporting air quality on a daily basis. It is a measure of how air pollution affects one's health within a short time period. The purpose of the AQI is to help people know how the local air quality impacts their health. The Environmental Protection Agency (EPA) calculates the AQI for five major air pollutants, for which national air quality standards have been established to safeguard public health.
#
# ### --->Ground-level ozone
# ### --->Particle pollution/particulate matter (PM2.5/pm 10)
# ### --->Carbon Monoxide
# ### --->Sulfur dioxide
# ### --->Nitrogen dioxide
# ### The higher the AQI value, the greater the level of air pollution and the greater the health concerns. The concept of AQI has been widely used in many developed countries for over the last three decades. AQI quickly disseminates air quality information in real-time.

# %% [markdown]
# ## Importing Libraries

# %%
## Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Numerical_Values = ['0-50','51-100','101-150','151-200','201-300','301-500']
color = ['Green','Yellow','Orange','Red','Purple','Maroon']
Air_Quality_Index_Level_of_Health_concern = ['Good','Moderate','Unhealthy for sensitive groups','Unhealthy','Very Unhealthy','Hazardous']
AQI_Info = pd.DataFrame({'Numerical Values of AQI':Numerical_Values,'Color':color,'Air Quality Index Level of Health concern':Air_Quality_Index_Level_of_Health_concern})
AQI_Info
# Out:
#   Numerical Values of AQI   Color Air Quality Index Level of Health concern
# 0                    0-50   Green                                      Good
# 1                  51-100  Yellow                                  Moderate
# 2                 101-150  Orange            Unhealthy for sensitive groups
# 3                 151-200     Red                                 Unhealthy
# 4                 201-300  Purple                            Very Unhealthy
# 5                 301-500  Maroon                                 Hazardous

# %% [markdown]
# # Data Analysis and Visualization

# %% [markdown]
# ## Read data

# %%
city_day = pd.read_csv('city_day.csv')
city_hour = pd.read_csv('city_hour.csv')
station_day = pd.read_csv('station_day.csv')
station_hour = pd.read_csv('station_hour.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# ## Lets review the files one by one

# %%
## city_day
print("City Day Data", city_day.shape)
print(city_day.columns.tolist())
city_day.head()
# Out:
# City Day Data (29531, 16)
# ['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket']
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
## city_hour
print("City Hour Data", city_hour.shape)
print(city_hour.columns.tolist())
city_hour.head()
# Out:
# City Hour Data (707875, 16)
# ['City', 'Datetime', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket']
#         City          Datetime  PM2.5  PM10    NO    NO2    NOx  NH3    CO  \
# 0  Ahmedabad  01-01-2015 01:00    NaN   NaN  1.00  40.01  36.37  NaN  1.00
# 1  Ahmedabad  01-01-2015 02:00    NaN   NaN  0.02  27.75  19.73  NaN  0.02
# 2  Ahmedabad  01-01-2015 03:00    NaN   NaN  0.08  19.32  11.08  NaN  0.08
# 3  Ahmedabad  01-01-2015 04:00    NaN   NaN  0.30  16.45   9.20  NaN  0.30
# 4  Ahmedabad  01-01-2015 05:00    NaN   NaN  0.12  14.90   7.85  NaN  0.12
#
#       SO2      O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  122.07     NaN      0.0      0.0     0.0  NaN        NaN
# 1   85.90     NaN      0.0      0.0     0.0  NaN        NaN
# 2   52.83     NaN      0.0      0.0     0.0  NaN        NaN
# 3   39.53  153.58      0.0      0.0     0.0  NaN        NaN
# 4   32.63     NaN      0.0      0.0     0.0  NaN        NaN

# %%
## station_day
print("Station Day Data", station_day.shape)
print(station_day.columns.tolist())
station_day.head()
# Out:
# Station Day Data (108035, 16)
# ['StationId', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket']
#   StationId        Date  PM2.5    PM10    NO    NO2    NOx    NH3    CO  \
# 0     AP001  24-11-2017  71.36  115.75  1.75  20.65  12.40  12.19  0.10
# 1     AP001  25-11-2017  81.40  124.50  1.44  20.50  12.08  10.72  0.12
# 2     AP001  26-11-2017  78.32  129.06  1.26  26.00  14.85  10.28  0.14
# 3     AP001  27-11-2017  88.76  135.32  6.60  30.85  21.77  12.91  0.11
# 4     AP001  28-11-2017  64.18  104.09  2.56  28.07  17.01  11.42  0.09
#
#      SO2      O3  Benzene  Toluene  Xylene    AQI AQI_Bucket
# 0  10.76  109.26     0.17     5.92    0.10    NaN        NaN
# 1  15.24  127.09     0.20     6.50    0.06  184.0   Moderate
# 2  26.96  117.44     0.22     7.95    0.08  197.0   Moderate
# 3  33.59  111.81     0.29     7.63    0.12  198.0   Moderate
# 4  19.00  138.18     0.17     5.02    0.07  188.0   Moderate

# %%
## station_hour
print("Station Hour Data", station_hour.shape)
print(station_hour.columns.tolist())
station_hour.head()
# Out:
# Station Hour Data (1048575, 16)
# ['StationId', 'Datetime', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket']
#   StationId          Datetime  PM2.5    PM10    NO    NO2    NOx    NH3   CO  \
# 0     AP001  24-11-2017 17:00  60.50   98.00  2.35  30.80  18.25   8.50  0.1
# 1     AP001  24-11-2017 18:00  65.50  111.25  2.70  24.20  15.07   9.77  0.1
# 2     AP001  24-11-2017 19:00  80.00  132.00  2.10  25.18  15.15  12.02  0.1
# 3     AP001  24-11-2017 20:00  81.50  133.25  1.95  16.25  10.23  11.58  0.1
# 4     AP001  24-11-2017 21:00  75.25  116.00  1.43  17.48  10.43  12.03  0.1
#
#      SO2      O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  11.85  126.40      0.1     6.10    0.10  NaN        NaN
# 1  13.17  117.12      0.1     6.25    0.15  NaN        NaN
# 2  12.08   98.98      0.2     5.98    0.18  NaN        NaN
# 3  10.47  112.20      0.2     6.72    0.10  NaN        NaN
# 4   9.12  106.35      0.2     5.75    0.08  NaN        NaN

# %%
## Convert into datetime
city_day['Date'] = pd.to_datetime(city_day['Date'])
city_day['Year'] = city_day['Date'].dt.year
city_day['Month'] = city_day['Date'].dt.month
city_day['day'] = city_day['Date'].dt.day
station_day['Date'] = pd.to_datetime(station_day['Date'])
station_day['Year'] = station_day['Date'].dt.year
station_day['Month'] = station_day['Date'].dt.month
station_day['day'] = station_day['Date'].dt.day

# %%
city_day.head()
# Out:
#         City       Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad 2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad 2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad 2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad 2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad 2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket  Year  Month  day
# 0  133.36     0.00     0.02    0.00  NaN        NaN  2015      1    1
# 1   34.06     3.68     5.50    3.77  NaN        NaN  2015      1    2
# 2   30.70     6.80    16.40    2.25  NaN        NaN  2015      1    3
# 3   36.08     4.43    10.14    1.00  NaN        NaN  2015      1    4
# 4   39.31     7.01    18.89    2.78  NaN        NaN  2015      1    5

# %%
station_day.head()
# Out:
#   StationId       Date  PM2.5    PM10    NO    NO2    NOx    NH3    CO    SO2  \
# 0     AP001 2017-11-24  71.36  115.75  1.75  20.65  12.40  12.19  0.10  10.76
# 1     AP001 2017-11-25  81.40  124.50  1.44  20.50  12.08  10.72  0.12  15.24
# 2     AP001 2017-11-26  78.32  129.06  1.26  26.00  14.85  10.28  0.14  26.96
# 3     AP001 2017-11-27  88.76  135.32  6.60  30.85  21.77  12.91  0.11  33.59
# 4     AP001 2017-11-28  64.18  104.09  2.56  28.07  17.01  11.42  0.09  19.00
#
#        O3  Benzene  Toluene  Xylene    AQI AQI_Bucket  Year  Month  day
# 0  109.26     0.17     5.92    0.10    NaN        NaN  2017     11   24
# 1  127.09     0.20     6.50    0.06  184.0   Moderate  2017     11   25
# 2  117.44     0.22     7.95    0.08  197.0   Moderate  2017     11   26
# 3  111.81     0.29     7.63    0.12  198.0   Moderate  2017     11   27
# 4  138.18     0.17     5.02    0.07  188.0   Moderate  2017     11   28

# %%
city_day.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  24933.000000  18391.000000  25949.000000  25946.000000  25346.000000
# mean      67.450578    118.127103     17.574730     28.560659     32.309123
# std       64.661449     90.605110     22.785846     24.474746     31.646011
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       28.820000     56.255000      5.630000     11.750000     12.820000
# 50%       48.570000     95.680000      9.890000     21.690000     23.520000
# 75%       80.590000    149.745000     19.950000     37.620000     40.127500
# max      949.990000   1000.000000    390.680000    362.210000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  19203.000000  27472.000000  25677.000000  25509.000000  23908.000000
# mean      23.483476      2.248598     14.531977     34.491430      3.280840
# std       25.684275      6.962884     18.133775     21.694928     15.811136
# min        0.010000      0.000000      0.010000      0.010000      0.000000
# 25%        8.580000      0.510000      5.670000     18.860000      0.120000
# 50%       15.850000      0.890000      9.160000     30.840000      1.070000
# 75%       30.020000      1.450000     15.220000     45.570000      3.080000
# max      352.890000    175.810000    193.860000    257.730000    455.030000
#
#             Toluene        Xylene           AQI          Year         Month  \
# count  21490.000000  11422.000000  24850.000000  29531.000000  29531.000000
# mean       8.700972      3.070128    166.463581   2017.887914      6.267143
# std       19.969164      6.323247    140.696585      1.533783      3.431974
# min        0.000000      0.000000     13.000000   2015.000000      1.000000
# 25%        0.600000      0.140000     81.000000   2017.000000      3.000000
# 50%        2.970000      0.980000    118.000000   2018.000000      6.000000
# 75%        9.150000      3.350000    208.000000   2019.000000      9.000000
# max      454.850000    170.370000   2049.000000   2020.000000     12.000000
#
#                 day
# count  29531.000000
# mean      15.762758
# std        8.804537
# min        1.000000
# 25%        8.000000
# 50%       16.000000
# 75%       23.000000
# max       31.000000

# %% [markdown]
# # Cities
# ## How many cities do we have here?

# %%
print("Total cities", len(city_day['City'].unique()))
city_day['City'].unique().tolist()
# Out:
# Total cities 26
# ['Ahmedabad',
#  'Aizawl',
#  'Amaravati',
#  'Amritsar',
#  'Bengaluru',
#  'Bhopal',
#  'Brajrajnagar',
#  'Chandigarh',
#  'Chennai',
#  'Coimbatore',
#  'Delhi',
#  'Ernakulam',
#  'Gurugram',
#  'Guwahati',
#  'Hyderabad',
#  'Jaipur',
#  'Jorapokhar',
#  'Kochi',
#  'Kolkata',
#  'Lucknow',
#  'Mumbai',
#  'Patna',
#  'Shillong',
#  'Talcher',
#  'Thiruvananthapuram',
#  'Visakhapatnam']

# %% [markdown]
# ### Lets have a look at the pollutants and how they are distributed
#
# Observations:
#
# - PM2.5, O3 are usually high throughout the year
# - CO has been found consistently low over the years

# %%
pollutants = ['PM2.5','PM10', 'NO', 'NOx','NO2','CO','NH3','O3','SO2','Benzene','Toluene','Xylene']
df = city_day.set_index('Date')
axes = df[pollutants].plot(marker='.',alpha = 0.5, linestyle = 'None', figsize = (16,20), subplots = True)
for ax in axes:
    ax.set_xlabel('Years')
    ax.set_ylabel('ug/m3')

# %% [markdown]
# ## How are the AQI Buckets distributed?

# %%
plt.title('Distribution of AQI Buckets 2015-2020')
sns.countplot(x='AQI_Bucket', data=city_day, hue='Year');

# %% [markdown]
# - Overall we see we have a large number of Moderate and Satisfactory bucket counts which is a good thing and low number of Poor and Severe buckets over 2015-2020.
# - If we observe carefully, 2019 has highest Moderate and Satisfactory buckets which can be explained by lower pollution levels by the lockdown.
# - And as compared to the previous years 2018 & 2019, for all the buckets we see a steep decline in 2020, and in case of "Good" bucket - higher number than previous years which can be seen as a positive sign.

# %% [markdown]
# ### Lets study the AQI levels themselves

# %%
## AQI
print(f"Minimum and maximum range of AQI: {city_day.AQI.min()} - {city_day.AQI.max()}")
plt.title('AQI levels over 2015 to 2020')
sns.lineplot(x='Year',y='AQI', data=city_day);
# Out:
# Minimum and maximum range of AQI: 13.0 - 2049.0

# %% [markdown]
# We observe a general decline in the AQI levels over the years which shows increase in Air Quality

# %% [markdown]
# ### Lets observe the AQI levels of some of the metro cities over the years.

# %%
data = city_day[(city_day['City'] == 'Mumbai') | (city_day['City'] == 'Delhi') | (city_day['City'] == 'Bengaluru') | (city_day['City'] == 'Ahmedabad') | (city_day['City'] == 'Chennai')]
plt.title('AQI Levels of some metro cities 2015-2020')
sns.lineplot(x='Year',y='AQI', data=data, hue='City');

# %% [markdown]
# ### In 2020 how did the AQI levels vary?

# %%
data = city_day[city_day['Year'] == 2020]
plt.title('AQI Levels in the year 2020')
sns.lineplot(x='Month', y='AQI', data=data);

# %% [markdown]
# Even before the nationwide lockdown declared by the PM (24th March 2020), individual states were already in lockdown before that and hence we see the steep decline in the AQI from Feb.

# %% [markdown]
# ## Lets compare for Delhi & Mumbai in 2020 both hotspots for pollutants.

# %%
data = city_day[city_day['Year'] == 2020][(city_day['City'] == 'Mumbai') | (city_day['City'] == 'Delhi')]
plt.title('AQI Levels of Delhi & Mumbai in 2020')
sns.lineplot(x='Month',y='AQI', data=data, hue='City');
# Out:
# <ipython-input-18-a6852214fbcc>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = city_day[city_day['Year'] == 2020][(city_day['City'] == 'Mumbai') | (city_day['City'] == 'Delhi')]

# %% [markdown]
# ## Visual Analysis of Our Data sets one by one

# %% [markdown]
# # Data Cleaning Data Preprocessing

# %% [markdown]
# ## Data sets

# %%
city_day = pd.read_csv('city_day.csv')
city_hour = pd.read_csv('city_hour.csv')
station_day = pd.read_csv('station_day.csv')
station_hour = pd.read_csv('station_hour.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# ## Lets clean the dataset one by one

# %% [markdown]
# ### 1. City_day

# %%
city_day.head()
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
city_day.shape
# Out:
# (29531, 16)

# %%
city_day.dtypes
# Out:
# City           object
# Date           object
# PM2.5         float64
# PM10          float64
# NO            float64
# NO2           float64
# NOx           float64
# NH3           float64
# CO            float64
# SO2           float64
# O3            float64
# Benzene       float64
# Toluene       float64
# Xylene        float64
# AQI           float64
# AQI_Bucket     object
# dtype: object

# %%
city_day.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %%
## Percentage null values in each columns..
(city_day.isnull().sum()/city_day.shape[0]*100).sort_values(ascending =False)
# Out:
# Xylene        61.322001
# PM10          37.723071
# NH3           34.973418
# Toluene       27.229014
# Benzene       19.041008
# AQI           15.851139
# AQI_Bucket    15.851139
# PM2.5         15.570079
# NOx           14.171549
# O3            13.619586
# SO2           13.050692
# NO2           12.139785
# NO            12.129626
# CO             6.972334
# City           0.000000
# Date           0.000000
# dtype: float64

# %%
city_day.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  24933.000000  18391.000000  25949.000000  25946.000000  25346.000000
# mean      67.450578    118.127103     17.574730     28.560659     32.309123
# std       64.661449     90.605110     22.785846     24.474746     31.646011
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       28.820000     56.255000      5.630000     11.750000     12.820000
# 50%       48.570000     95.680000      9.890000     21.690000     23.520000
# 75%       80.590000    149.745000     19.950000     37.620000     40.127500
# max      949.990000   1000.000000    390.680000    362.210000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  19203.000000  27472.000000  25677.000000  25509.000000  23908.000000
# mean      23.483476      2.248598     14.531977     34.491430      3.280840
# std       25.684275      6.962884     18.133775     21.694928     15.811136
# min        0.010000      0.000000      0.010000      0.010000      0.000000
# 25%        8.580000      0.510000      5.670000     18.860000      0.120000
# 50%       15.850000      0.890000      9.160000     30.840000      1.070000
# 75%       30.020000      1.450000     15.220000     45.570000      3.080000
# max      352.890000    175.810000    193.860000    257.730000    455.030000
#
#             Toluene        Xylene           AQI
# count  21490.000000  11422.000000  24850.000000
# mean       8.700972      3.070128    166.463581
# std       19.969164      6.323247    140.696585
# min        0.000000      0.000000     13.000000
# 25%        0.600000      0.140000     81.000000
# 50%        2.970000      0.980000    118.000000
# 75%        9.150000      3.350000    208.000000
# max      454.850000    170.370000   2049.000000

# %% [markdown]
# ### we are going to fill the null values with 'ffill' method

# %%
city_day['PM2.5'].fillna(method = 'ffill',inplace = True)
city_day['PM10'].fillna(method = 'ffill',inplace = True)
city_day['NO'].fillna(method = 'ffill',inplace = True)
city_day['NO2'].fillna(method = 'ffill',inplace = True)
city_day['NOx'].fillna(method = 'ffill',inplace = True)
city_day['NH3'].fillna(method = 'ffill',inplace = True)
city_day['CO'].fillna(method = 'ffill',inplace = True)
city_day['SO2'].fillna(method = 'ffill',inplace = True)
city_day['O3'].fillna(method = 'ffill',inplace = True)
city_day['Benzene'].fillna(method = 'ffill',inplace = True)
city_day['Toluene'].fillna(method = 'ffill',inplace = True)
city_day['Xylene'].fillna(method = 'ffill',inplace = True)

# %%
city_day.isnull().sum()
# Out:
# City             0
# Date             0
# PM2.5           27
# PM10          1594
# NO               0
# NO2              0
# NOx              0
# NH3           2009
# CO               0
# SO2              0
# O3               0
# Benzene          0
# Toluene          0
# Xylene           0
# AQI           4681
# AQI_Bucket    4681
# dtype: int64

# %% [markdown]
# ### As we can see some pollutant still have null values, so we are going to fill these values with there mean of particular pollutant

# %%
city_day.describe(include='all')
# Out:
#          City        Date         PM2.5          PM10            NO  \
# count   29531       29531  29504.000000  27937.000000  29531.000000
# unique     26        2009           NaN           NaN           NaN
# top     Delhi  2020-06-03           NaN           NaN           NaN
# freq     2009          26           NaN           NaN           NaN
# mean      NaN         NaN     66.130899     95.070437     17.201890
# std       NaN         NaN     64.130750     86.577554     23.245966
# min       NaN         NaN      0.040000      0.010000      0.020000
# 25%       NaN         NaN     29.160000     31.580000      5.900000
# 50%       NaN         NaN     46.850000     72.380000      9.280000
# 75%       NaN         NaN     78.652500    122.290000     18.560000
# max       NaN         NaN    949.990000   1000.000000    390.680000
#
#                  NO2           NOx           NH3            CO           SO2  \
# count   29531.000000  29531.000000  27522.000000  29531.000000  29531.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       26.909513     32.611069     22.359410      2.292734     15.650236
# std        23.671982     33.829601     26.695912      6.824266     20.583528
# min         0.010000      0.000000      0.010000      0.000000      0.010000
# 25%        11.630000     13.180000      7.820000      0.500000      5.740000
# 50%        19.720000     21.980000     13.395000      0.910000      8.950000
# 75%        35.030000     38.660000     25.500000      1.490000     15.840000
# max       362.210000    467.630000    352.890000    175.810000    193.860000
#
#                   O3       Benzene       Toluene        Xylene           AQI  \
# count   29531.000000  29531.000000  29531.000000  29531.000000  24850.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       34.130603      3.130408      7.027591      2.864628    166.463581
# std        21.631257     15.988058     17.841550      5.383474    140.696585
# min         0.010000      0.000000      0.000000      0.000000     13.000000
# 25%        18.860000      0.050000      0.280000      0.180000     81.000000
# 50%        31.480000      0.670000      1.720000      1.250000    118.000000
# 75%        44.215000      2.750000      6.710000      2.695000    208.000000
# max       257.730000    455.030000    454.850000    170.370000   2049.000000
#
#        AQI_Bucket
# count       24850
# unique          6
# top      Moderate
# freq         8829
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
city_day.fillna({'PM2.5':66.130899,'PM10':95.07043,'NH3':22.3594,'AQI':166.463581},inplace = True)

# %%
city_day.isnull().sum()
# Out:
# City             0
# Date             0
# PM2.5            0
# PM10             0
# NO               0
# NO2              0
# NOx              0
# NH3              0
# CO               0
# SO2              0
# O3               0
# Benzene          0
# Toluene          0
# Xylene           0
# AQI              0
# AQI_Bucket    4681
# dtype: int64

# %% [markdown]
# ### Now we can see here AQI_Bucket has 4681 missing values so have to fill these column according to his range
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Calculating the AQI Bucket and the NAN value present

# %%
## AQI bucketing
def get_AQI_bucket(x):
    if x<= 50:
        return "Good"
    elif x>50 and x <= 100:
        return "Satisfactory"
    elif x>100 and x<= 200:
        return "Moderate"
    elif x>200 and x<= 300:
        return  "Poor"
    elif x>300 and x<= 400:
        return  "Very Poor"
    elif x>400:
        return  "Severe"
    else:
        return '0'
city_day["AQI_Bucket"] = city_day["AQI_Bucket"].fillna(city_day["AQI"].apply(lambda x: get_AQI_bucket(x)))

# %%
city_day
# Out:
#                 City        Date      PM2.5      PM10     NO    NO2    NOx  \
# 0          Ahmedabad  2015-01-01  66.130899  95.07043   0.92  18.22  17.15
# 1          Ahmedabad  2015-01-02  66.130899  95.07043   0.97  15.69  16.46
# 2          Ahmedabad  2015-01-03  66.130899  95.07043  17.40  19.30  29.70
# 3          Ahmedabad  2015-01-04  66.130899  95.07043   1.70  18.48  17.97
# 4          Ahmedabad  2015-01-05  66.130899  95.07043  22.10  21.42  37.76
# ...              ...         ...        ...       ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.020000  50.94000   7.68  25.06  19.54
# 29527  Visakhapatnam  2020-06-28  24.380000  74.09000   3.42  26.06  16.53
# 29528  Visakhapatnam  2020-06-29  22.910000  65.73000   3.45  29.53  18.33
# 29529  Visakhapatnam  2020-06-30  16.640000  49.97000   4.05  29.26  18.80
# 29530  Visakhapatnam  2020-07-01  15.000000  66.00000   0.40  26.85  14.05
#
#            NH3     CO    SO2      O3  Benzene  Toluene  Xylene         AQI  \
# 0      22.3594   0.92  27.64  133.36     0.00     0.02    0.00  166.463581
# 1      22.3594   0.97  24.55   34.06     3.68     5.50    3.77  166.463581
# 2      22.3594  17.40  29.07   30.70     6.80    16.40    2.25  166.463581
# 3      22.3594   1.70  18.59   36.08     4.43    10.14    1.00  166.463581
# 4      22.3594  22.10  39.33   39.31     7.01    18.89    2.78  166.463581
# ...        ...    ...    ...     ...      ...      ...     ...         ...
# 29526  12.4700   0.47   8.55   23.30     2.24    12.07    0.73   41.000000
# 29527  11.9900   0.52  12.72   30.14     0.74     2.21    0.38   70.000000
# 29528  10.7100   0.48   8.42   30.96     0.01     0.01    0.00   68.000000
# 29529  10.0300   0.52   9.84   28.30     0.00     0.00    0.00   54.000000
# 29530   5.2000   0.59   2.10   17.05     0.00     0.00    0.00   50.000000
#
#          AQI_Bucket
# 0          Moderate
# 1          Moderate
# 2          Moderate
# 3          Moderate
# 4          Moderate
# ...             ...
# 29526          Good
# 29527  Satisfactory
# 29528  Satisfactory
# 29529  Satisfactory
# 29530          Good
#
# [29531 rows x 16 columns]

# %%
city_day.isnull().sum()
# Out:
# City          0
# Date          0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# NH3           0
# CO            0
# SO2           0
# O3            0
# Benzene       0
# Toluene       0
# Xylene        0
# AQI           0
# AQI_Bucket    0
# dtype: int64

# %% [markdown]
# ### Now we can see all missing values are filled with there perfect value

# %% [markdown]
# ## 2.city_hour

# %%
city_hour.head()
# Out:
#         City          Datetime  PM2.5  PM10    NO    NO2    NOx  NH3    CO  \
# 0  Ahmedabad  01-01-2015 01:00    NaN   NaN  1.00  40.01  36.37  NaN  1.00
# 1  Ahmedabad  01-01-2015 02:00    NaN   NaN  0.02  27.75  19.73  NaN  0.02
# 2  Ahmedabad  01-01-2015 03:00    NaN   NaN  0.08  19.32  11.08  NaN  0.08
# 3  Ahmedabad  01-01-2015 04:00    NaN   NaN  0.30  16.45   9.20  NaN  0.30
# 4  Ahmedabad  01-01-2015 05:00    NaN   NaN  0.12  14.90   7.85  NaN  0.12
#
#       SO2      O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  122.07     NaN      0.0      0.0     0.0  NaN        NaN
# 1   85.90     NaN      0.0      0.0     0.0  NaN        NaN
# 2   52.83     NaN      0.0      0.0     0.0  NaN        NaN
# 3   39.53  153.58      0.0      0.0     0.0  NaN        NaN
# 4   32.63     NaN      0.0      0.0     0.0  NaN        NaN

# %%
city_hour.shape
# Out:
# (707875, 16)

# %%
city_hour.isnull().sum()
# Out:
# City               0
# Datetime           0
# PM2.5         145088
# PM10          296737
# NO            116632
# NO2           117122
# NOx           123224
# NH3           272542
# CO             86517
# SO2           130373
# O3            129208
# Benzene       163646
# Toluene       220607
# Xylene        455829
# AQI           129080
# AQI_Bucket    129080
# dtype: int64

# %% [markdown]
# ### we are going to fill the null values with 'ffill' method

# %%
city_hour['PM2.5'].fillna(method = 'ffill',inplace = True)
city_hour['PM10'].fillna(method = 'ffill',inplace = True)
city_hour['NO'].fillna(method = 'ffill',inplace = True)
city_hour['NO2'].fillna(method = 'ffill',inplace = True)
city_hour['NOx'].fillna(method = 'ffill',inplace = True)
city_hour['NH3'].fillna(method = 'ffill',inplace = True)
city_hour['CO'].fillna(method = 'ffill',inplace = True)
city_hour['SO2'].fillna(method = 'ffill',inplace = True)
city_hour['O3'].fillna(method = 'ffill',inplace = True)
city_hour['Benzene'].fillna(method = 'ffill',inplace = True)
city_hour['Toluene'].fillna(method = 'ffill',inplace = True)
city_hour['Xylene'].fillna(method = 'ffill',inplace = True)

# %%
city_hour.isnull().sum()
# Out:
# City               0
# Datetime           0
# PM2.5            665
# PM10           38274
# NO                 0
# NO2                0
# NOx                0
# NH3            48192
# CO                 0
# SO2                0
# O3                 3
# Benzene            0
# Toluene            0
# Xylene             0
# AQI           129080
# AQI_Bucket    129080
# dtype: int64

# %% [markdown]
# ### As we can see some pollutant still have null values, so we are going to fill these values with there mean of particular pollutant

# %%
city_hour.describe(include='all')
# Out:
#           City          Datetime          PM2.5           PM10             NO  \
# count   707875            707875  707210.000000  669601.000000  707875.000000
# unique      26             48192            NaN            NaN            NaN
# top      Delhi  24-03-2020 05:00            NaN            NaN            NaN
# freq     48192                26            NaN            NaN            NaN
# mean       NaN               NaN      65.518777      94.909327      17.268706
# std        NaN               NaN      75.247013      96.558741      33.156022
# min        NaN               NaN       0.010000       0.010000       0.010000
# 25%        NaN               NaN      26.000000      31.580000       3.750000
# 50%        NaN               NaN      44.500000      72.380000       8.240000
# 75%        NaN               NaN      74.870000     118.330000      15.590000
# max        NaN               NaN     999.990000    1000.000000     499.990000
#
#                   NO2            NOx            NH3             CO  \
# count   707875.000000  707875.000000  659683.000000  707875.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean        26.812960      33.473718      21.442548       2.334911
# std         28.740254      44.296272      27.287127      11.103848
# min          0.010000       0.000000       0.010000       0.000000
# 25%          9.880000      10.460000       7.310000       0.400000
# 50%         17.640000      18.900000      12.870000       0.810000
# 75%         33.770000      36.560000      24.270000       1.420000
# max        499.510000     498.610000     499.970000     498.570000
#
#                   SO2             O3        Benzene        Toluene  \
# count   707875.000000  707872.000000  707875.000000  707875.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean        15.018375      35.085841       3.331737       7.340007
# std         22.606064      31.071894      19.573137      22.189300
# min          0.010000       0.010000       0.000000       0.000000
# 25%          4.880000      13.420000       0.000000       0.100000
# 50%          7.890000      26.720000       0.490000       1.290000
# 75%         14.890000      46.340000       2.430000       6.060000
# max        199.960000     497.620000     498.070000     499.400000
#
#                Xylene            AQI AQI_Bucket
# count   707875.000000  578795.000000     578795
# unique            NaN            NaN          6
# top               NaN            NaN   Moderate
# freq              NaN            NaN     198991
# mean         2.931787     166.413500        NaN
# std          7.729179     162.112729        NaN
# min          0.000000       8.000000        NaN
# 25%          0.180000      79.000000        NaN
# 50%          0.950000     116.000000        NaN
# 75%          2.620000     208.000000        NaN
# max        499.990000    3133.000000        NaN

# %%
city_hour.fillna({'PM2.5':65.518777,'PM10':94.909327,'NH3':21.442548,'AQI':166.413500},inplace = True)

# %%
city_hour.isnull().sum()
# Out:
# City               0
# Datetime           0
# PM2.5              0
# PM10               0
# NO                 0
# NO2                0
# NOx                0
# NH3                0
# CO                 0
# SO2                0
# O3                 3
# Benzene            0
# Toluene            0
# Xylene             0
# AQI                0
# AQI_Bucket    129080
# dtype: int64

# %% [markdown]
# ### Now we can see here AQI_Bucket has 129080 missing values so have to fill these column according to his range
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Calculating the AQI Bucket and the NAN value present

# %%
## AQI bucketing
def get_AQI_bucket(x):
    if x<= 50:
        return "Good"
    elif x>50 and x <= 100:
        return "Satisfactory"
    elif x>100 and x<= 200:
        return "Moderate"
    elif x>200 and x<= 300:
        return  "Poor"
    elif x>300 and x<= 400:
        return  "Very Poor"
    elif x>400:
        return  "Severe"
    else:
        return '0'
city_hour["AQI_Bucket"] = city_hour["AQI_Bucket"].fillna(city_hour["AQI"].apply(lambda x: get_AQI_bucket(x)))

# %%
city_hour
# Out:
#                  City          Datetime      PM2.5       PM10    NO    NO2  \
# 0           Ahmedabad  01-01-2015 01:00  65.518777  94.909327  1.00  40.01
# 1           Ahmedabad  01-01-2015 02:00  65.518777  94.909327  0.02  27.75
# 2           Ahmedabad  01-01-2015 03:00  65.518777  94.909327  0.08  19.32
# 3           Ahmedabad  01-01-2015 04:00  65.518777  94.909327  0.30  16.45
# 4           Ahmedabad  01-01-2015 05:00  65.518777  94.909327  0.12  14.90
# ...               ...               ...        ...        ...   ...    ...
# 707870  Visakhapatnam  30-06-2020 20:00   9.500000  36.000000  2.75  25.57
# 707871  Visakhapatnam  30-06-2020 21:00  17.250000  49.250000  3.62  33.20
# 707872  Visakhapatnam  30-06-2020 22:00  36.000000  71.000000  2.20  30.80
# 707873  Visakhapatnam  30-06-2020 23:00  15.750000  63.000000  1.02  28.90
# 707874  Visakhapatnam  01-07-2020 00:00  15.000000  66.000000  0.40  26.85
#
#           NOx        NH3    CO     SO2      O3  Benzene  Toluene  Xylene  \
# 0       36.37  21.442548  1.00  122.07     NaN      0.0      0.0     0.0
# 1       19.73  21.442548  0.02   85.90     NaN      0.0      0.0     0.0
# 2       11.08  21.442548  0.08   52.83     NaN      0.0      0.0     0.0
# 3        9.20  21.442548  0.30   39.53  153.58      0.0      0.0     0.0
# 4        7.85  21.442548  0.12   32.63  153.58      0.0      0.0     0.0
# ...       ...        ...   ...     ...     ...      ...      ...     ...
# 707870  15.85   4.570000  0.62    1.85   27.75      0.0      0.0     0.0
# 707871  20.62   3.780000  0.76    2.02   25.58      0.0      0.0     0.0
# 707872  18.20   3.670000  0.58    1.77   26.15      0.0      0.0     0.0
# 707873  16.00   3.800000  0.49    0.75   15.82      0.0      0.0     0.0
# 707874  14.05   5.200000  0.59    2.10   17.05      0.0      0.0     0.0
#
#              AQI    AQI_Bucket
# 0       166.4135      Moderate
# 1       166.4135      Moderate
# 2       166.4135      Moderate
# 3       166.4135      Moderate
# 4       166.4135      Moderate
# ...          ...           ...
# 707870   51.0000  Satisfactory
# 707871   51.0000  Satisfactory
# 707872   50.0000          Good
# 707873   50.0000          Good
# 707874   50.0000          Good
#
# [707875 rows x 16 columns]

# %% [markdown]
# ### Now we can see all missing values are filled with there perfect value

# %% [markdown]
# ## 3.station_day

# %%
station_day.head()
# Out:
#   StationId        Date  PM2.5    PM10    NO    NO2    NOx    NH3    CO  \
# 0     AP001  24-11-2017  71.36  115.75  1.75  20.65  12.40  12.19  0.10
# 1     AP001  25-11-2017  81.40  124.50  1.44  20.50  12.08  10.72  0.12
# 2     AP001  26-11-2017  78.32  129.06  1.26  26.00  14.85  10.28  0.14
# 3     AP001  27-11-2017  88.76  135.32  6.60  30.85  21.77  12.91  0.11
# 4     AP001  28-11-2017  64.18  104.09  2.56  28.07  17.01  11.42  0.09
#
#      SO2      O3  Benzene  Toluene  Xylene    AQI AQI_Bucket
# 0  10.76  109.26     0.17     5.92    0.10    NaN        NaN
# 1  15.24  127.09     0.20     6.50    0.06  184.0   Moderate
# 2  26.96  117.44     0.22     7.95    0.08  197.0   Moderate
# 3  33.59  111.81     0.29     7.63    0.12  198.0   Moderate
# 4  19.00  138.18     0.17     5.02    0.07  188.0   Moderate

# %%
station_day.shape
# Out:
# (108035, 16)

# %%
station_day.isnull().sum()
# Out:
# StationId         0
# Date              0
# PM2.5         21625
# PM10          42706
# NO            17106
# NO2           16547
# NOx           15500
# NH3           48105
# CO            12998
# SO2           25204
# O3            25568
# Benzene       31455
# Toluene       38702
# Xylene        85137
# AQI           21010
# AQI_Bucket    21010
# dtype: int64

# %% [markdown]
# ### we are going to fill the null values with 'ffill' method

# %%
station_day['PM2.5'].fillna(method = 'ffill',inplace = True)
station_day['PM10'].fillna(method = 'ffill',inplace = True)
station_day['NO'].fillna(method = 'ffill',inplace = True)
station_day['NO2'].fillna(method = 'ffill',inplace = True)
station_day['NOx'].fillna(method = 'ffill',inplace = True)
station_day['NH3'].fillna(method = 'ffill',inplace = True)
station_day['CO'].fillna(method = 'ffill',inplace = True)
station_day['SO2'].fillna(method = 'ffill',inplace = True)
station_day['O3'].fillna(method = 'ffill',inplace = True)
station_day['Benzene'].fillna(method = 'ffill',inplace = True)
station_day['Toluene'].fillna(method = 'ffill',inplace = True)
station_day['Xylene'].fillna(method = 'ffill',inplace = True)

# %%
station_day.isnull().sum()
# Out:
# StationId         0
# Date              0
# PM2.5             0
# PM10              0
# NO                0
# NO2               0
# NOx               0
# NH3               0
# CO                0
# SO2               0
# O3                0
# Benzene           0
# Toluene           0
# Xylene            0
# AQI           21010
# AQI_Bucket    21010
# dtype: int64

# %%
station_day.describe(include='all')
# Out:
#        StationId        Date          PM2.5           PM10             NO  \
# count     108035      108035  108035.000000  108035.000000  108035.000000
# unique       110        2009            NaN            NaN            NaN
# top        UP012  02-05-2020            NaN            NaN            NaN
# freq        2009         108            NaN            NaN            NaN
# mean         NaN         NaN      76.331760     130.706051      22.208852
# std          NaN         NaN      76.136824     114.559250      33.668653
# min          NaN         NaN       0.020000       0.010000       0.010000
# 25%          NaN         NaN      28.710000      45.000000       4.690000
# 50%          NaN         NaN      52.260000     102.380000      10.080000
# 75%          NaN         NaN      94.560000     164.175000      23.550000
# max          NaN         NaN    1000.000000    1000.000000     470.000000
#
#                   NO2            NOx            NH3             CO  \
# count   108035.000000  108035.000000  108035.000000  108035.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean        34.094640      39.670632      27.075086       1.658368
# std         29.977547      44.537631      28.241088       4.422291
# min          0.010000       0.000000       0.010000       0.000000
# 25%         14.000000      13.500000       7.760000       0.520000
# 50%         25.970000      25.260000      19.960000       0.930000
# 75%         45.460000      48.460000      34.850000       1.450000
# max        448.050000     467.630000     418.900000     175.810000
#
#                   SO2             O3        Benzene        Toluene  \
# count   108035.000000  108035.000000  108035.000000  108035.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean        12.644834      38.604680       3.183034      18.259476
# std         13.763347      48.359579      10.713126      34.062984
# min          0.010000       0.010000       0.000000       0.000000
# 25%          5.340000      17.050000       0.100000       0.390000
# 50%          9.210000      27.790000       1.040000       3.290000
# 75%         14.700000      45.690000       3.460000      17.620000
# max        195.650000     963.000000     455.030000     454.850000
#
#                Xylene           AQI AQI_Bucket
# count   108035.000000  87025.000000      87025
# unique            NaN           NaN          6
# top               NaN           NaN   Moderate
# freq              NaN           NaN      29417
# mean         2.057581    179.749290        NaN
# std          4.275254    131.324339        NaN
# min          0.000000      8.000000        NaN
# 25%          0.000000     86.000000        NaN
# 50%          0.400000    132.000000        NaN
# 75%          2.600000    254.000000        NaN
# max        170.370000   2049.000000        NaN

# %%
station_day.fillna({'AQI':179.749290},inplace = True)

# %%
station_day.isnull().sum()
# Out:
# StationId         0
# Date              0
# PM2.5             0
# PM10              0
# NO                0
# NO2               0
# NOx               0
# NH3               0
# CO                0
# SO2               0
# O3                0
# Benzene           0
# Toluene           0
# Xylene            0
# AQI               0
# AQI_Bucket    21010
# dtype: int64

# %% [markdown]
# ### Now we can see here AQI_Bucket has 21010 missing values so have to fill these column according to his range
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Calculating the AQI Bucket and the NAN value present

# %%
## AQI bucketing
def get_AQI_bucket(x):
    if x<= 50:
        return "Good"
    elif x>50 and x <= 100:
        return "Satisfactory"
    elif x>100 and x<= 200:
        return "Moderate"
    elif x>200 and x<= 300:
        return  "Poor"
    elif x>300 and x<= 400:
        return  "Very Poor"
    elif x>400:
        return  "Severe"
    else:
        return '0'
station_day["AQI_Bucket"] = station_day["AQI_Bucket"].fillna(station_day["AQI"].apply(lambda x: get_AQI_bucket(x)))

# %%
station_day
# Out:
#        StationId        Date  PM2.5    PM10     NO     NO2     NOx    NH3  \
# 0          AP001  24-11-2017  71.36  115.75   1.75   20.65   12.40  12.19
# 1          AP001  25-11-2017  81.40  124.50   1.44   20.50   12.08  10.72
# 2          AP001  26-11-2017  78.32  129.06   1.26   26.00   14.85  10.28
# 3          AP001  27-11-2017  88.76  135.32   6.60   30.85   21.77  12.91
# 4          AP001  28-11-2017  64.18  104.09   2.56   28.07   17.01  11.42
# ...          ...         ...    ...     ...    ...     ...     ...    ...
# 108030     WB013  27-06-2020   8.65   16.46  23.51   16.50   40.02  25.09
# 108031     WB013  28-06-2020  11.80   18.47  23.51   16.50   40.02  25.09
# 108032     WB013  29-06-2020  18.60   32.26  13.65  200.87  214.20  11.40
# 108033     WB013  30-06-2020  16.07   39.30   7.56   29.13   36.69  29.26
# 108034     WB013  01-07-2020  10.50   36.50   7.78   22.50   30.25  27.23
#
#           CO    SO2      O3  Benzene  Toluene  Xylene        AQI    AQI_Bucket
# 0       0.10  10.76  109.26     0.17     5.92    0.10  179.74929      Moderate
# 1       0.12  15.24  127.09     0.20     6.50    0.06  184.00000      Moderate
# 2       0.14  26.96  117.44     0.22     7.95    0.08  197.00000      Moderate
# 3       0.11  33.59  111.81     0.29     7.63    0.12  198.00000      Moderate
# 4       0.09  19.00  138.18     0.17     5.02    0.07  188.00000      Moderate
# ...      ...    ...     ...      ...      ...     ...        ...           ...
# 108030  0.69   4.36   30.59     1.32     7.26    2.42   50.00000          Good
# 108031  0.68   3.49   38.95     1.42     7.92    2.42   65.00000  Satisfactory
# 108032  0.78   5.12   38.17     3.52     8.64    2.42   63.00000  Satisfactory
# 108033  0.69   5.88   29.64     1.86     8.40    2.42   57.00000  Satisfactory
# 108034  0.58   2.80   13.10     1.31     7.39    2.42   59.00000  Satisfactory
#
# [108035 rows x 16 columns]

# %% [markdown]
# ### Now we can see all missing values are filled with 'ffill' method

# %% [markdown]
# ## 4.station_hour

# %%
station_hour.head()
# Out:
#   StationId          Datetime  PM2.5    PM10    NO    NO2    NOx    NH3   CO  \
# 0     AP001  24-11-2017 17:00  60.50   98.00  2.35  30.80  18.25   8.50  0.1
# 1     AP001  24-11-2017 18:00  65.50  111.25  2.70  24.20  15.07   9.77  0.1
# 2     AP001  24-11-2017 19:00  80.00  132.00  2.10  25.18  15.15  12.02  0.1
# 3     AP001  24-11-2017 20:00  81.50  133.25  1.95  16.25  10.23  11.58  0.1
# 4     AP001  24-11-2017 21:00  75.25  116.00  1.43  17.48  10.43  12.03  0.1
#
#      SO2      O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  11.85  126.40      0.1     6.10    0.10  NaN        NaN
# 1  13.17  117.12      0.1     6.25    0.15  NaN        NaN
# 2  12.08   98.98      0.2     5.98    0.18  NaN        NaN
# 3  10.47  112.20      0.2     6.72    0.10  NaN        NaN
# 4   9.12  106.35      0.2     5.75    0.08  NaN        NaN

# %%
station_hour.shape
# Out:
# (1048575, 16)

# %%
station_hour.isnull().sum()
# Out:
# StationId          0
# Datetime           0
# PM2.5         248389
# PM10          342735
# NO            230649
# NO2           217132
# NOx           192672
# NH3           466777
# CO            221049
# SO2           384227
# O3            250488
# Benzene       346715
# Toluene       376388
# Xylene        835117
# AQI           239544
# AQI_Bucket    239544
# dtype: int64

# %% [markdown]
# ### we are going to fill the null values with 'ffill' method

# %%
station_hour['PM2.5'].fillna(method = 'ffill',inplace = True)
station_hour['PM10'].fillna(method = 'ffill',inplace = True)
station_hour['NO'].fillna(method = 'ffill',inplace = True)
station_hour['NO2'].fillna(method = 'ffill',inplace = True)
station_hour['NOx'].fillna(method = 'ffill',inplace = True)
station_hour['NH3'].fillna(method = 'ffill',inplace = True)
station_hour['CO'].fillna(method = 'ffill',inplace = True)
station_hour['SO2'].fillna(method = 'ffill',inplace = True)
station_hour['O3'].fillna(method = 'ffill',inplace = True)
station_hour['Benzene'].fillna(method = 'ffill',inplace = True)
station_hour['Toluene'].fillna(method = 'ffill',inplace = True)
station_hour['Xylene'].fillna(method = 'ffill',inplace = True)

# %%
station_hour.isnull().sum()
# Out:
# StationId          0
# Datetime           0
# PM2.5              0
# PM10               0
# NO                 0
# NO2                0
# NOx                0
# NH3                0
# CO                 0
# SO2                0
# O3                 0
# Benzene            0
# Toluene            0
# Xylene             0
# AQI           239544
# AQI_Bucket    239544
# dtype: int64

# %%
station_hour.describe(include='all')
# Out:
#        StationId          Datetime         PM2.5          PM10            NO  \
# count    1048575           1048575  1.048575e+06  1.048575e+06  1.048575e+06
# unique        42             48192           NaN           NaN           NaN
# top        DL007  24-03-2020 05:00           NaN           NaN           NaN
# freq       48192                40           NaN           NaN           NaN
# mean         NaN               NaN  1.037582e+02  1.840226e+02  3.177905e+01
# std          NaN               NaN  1.003599e+02  1.490169e+02  6.234017e+01
# min          NaN               NaN  1.000000e-02  1.000000e-02  1.000000e-02
# 25%          NaN               NaN  4.100000e+01  8.400000e+01  4.000000e+00
# 50%          NaN               NaN  6.750000e+01  1.372500e+02  9.980000e+00
# 75%          NaN               NaN  1.382500e+02  2.337150e+02  2.577000e+01
# max          NaN               NaN  1.000000e+03  1.000000e+03  5.000000e+02
#
#                  NO2           NOx           NH3            CO           SO2  \
# count   1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    4.247370e+01  5.225320e+01  3.357030e+01  1.405888e+00  1.431761e+01
# std     4.020675e+01  7.273229e+01  2.817129e+01  2.449075e+00  1.203288e+01
# min     1.000000e-02  0.000000e+00  1.000000e-02  0.000000e+00  1.000000e-02
# 25%     1.629000e+01  1.415000e+01  1.912000e+01  5.000000e-01  7.620000e+00
# 50%     3.075000e+01  2.748000e+01  2.838000e+01  9.500000e-01  1.192000e+01
# 75%     5.490000e+01  5.703000e+01  4.055000e+01  1.520000e+00  1.835000e+01
# max     4.999700e+02  5.000000e+02  4.941100e+02  5.000000e+01  1.997700e+02
#
#                   O3       Benzene       Toluene        Xylene            AQI  \
# count   1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  809031.000000
# unique           NaN           NaN           NaN           NaN            NaN
# top              NaN           NaN           NaN           NaN            NaN
# freq             NaN           NaN           NaN           NaN            NaN
# mean    4.560102e+01  3.586940e+00  3.132507e+01  8.985887e-01     226.952556
# std     7.757408e+01  6.409659e+00  4.728984e+01  5.826560e+00     133.207479
# min     1.000000e-02  0.000000e+00  0.000000e+00  0.000000e+00      16.000000
# 25%     1.097000e+01  3.000000e-01  6.200000e-01  0.000000e+00     114.000000
# 50%     2.621000e+01  1.700000e+00  8.470000e+00  0.000000e+00     198.000000
# 75%     4.998000e+01  6.100000e+00  4.093000e+01  1.000000e-01     320.000000
# max     9.970000e+02  4.915100e+02  4.998000e+02  4.763100e+02    1113.000000
#
#        AQI_Bucket
# count      809031
# unique          6
# top      Moderate
# freq       263287
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
station_hour.fillna({'AQI':226.952556},inplace = True)

# %%
station_hour.isnull().sum()
# Out:
# StationId          0
# Datetime           0
# PM2.5              0
# PM10               0
# NO                 0
# NO2                0
# NOx                0
# NH3                0
# CO                 0
# SO2                0
# O3                 0
# Benzene            0
# Toluene            0
# Xylene             0
# AQI                0
# AQI_Bucket    239544
# dtype: int64

# %% [markdown]
# ### Now we can see here AQI_Bucket has 239544 missing values so have to fill these column according to his range
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Calculating the AQI Bucket and the NAN value present

# %%
## AQI bucketing
def get_AQI_bucket(x):
    if x<= 50:
        return "Good"
    elif x>50 and x <= 100:
        return "Satisfactory"
    elif x>100 and x<= 200:
        return "Moderate"
    elif x>200 and x<= 300:
        return  "Poor"
    elif x>300 and x<= 400:
        return  "Very Poor"
    elif x>400:
        return  "Severe"
    else:
        return '0'
station_hour["AQI_Bucket"] = station_hour["AQI_Bucket"].fillna(station_hour["AQI"].apply(lambda x: get_AQI_bucket(x)))

# %%
station_hour
# Out:
#         StationId          Datetime  PM2.5    PM10    NO    NO2    NOx    NH3  \
# 0           AP001  24-11-2017 17:00  60.50   98.00  2.35  30.80  18.25   8.50
# 1           AP001  24-11-2017 18:00  65.50  111.25  2.70  24.20  15.07   9.77
# 2           AP001  24-11-2017 19:00  80.00  132.00  2.10  25.18  15.15  12.02
# 3           AP001  24-11-2017 20:00  81.50  133.25  1.95  16.25  10.23  11.58
# 4           AP001  24-11-2017 21:00  75.25  116.00  1.43  17.48  10.43  12.03
# ...           ...               ...    ...     ...   ...    ...    ...    ...
# 1048570     DL032  08-05-2018 13:00  36.00  106.00  0.70  17.05   0.10   1.08
# 1048571     DL032  08-05-2018 14:00  31.00  114.00  0.70  17.05   0.10   1.00
# 1048572     DL032  08-05-2018 15:00  35.00  112.00  0.70  17.05   0.10   0.85
# 1048573     DL032  08-05-2018 16:00  44.00  108.00  0.70  17.05   5.52   1.58
# 1048574     DL032  08-05-2018 17:00  52.00  111.00  1.62  11.40  11.13   8.91
#
#            CO    SO2      O3  Benzene  Toluene  Xylene         AQI AQI_Bucket
# 0        0.10  11.85  126.40     0.10     6.10    0.10  226.952556       Poor
# 1        0.10  13.17  117.12     0.10     6.25    0.15  226.952556       Poor
# 2        0.10  12.08   98.98     0.20     5.98    0.18  226.952556       Poor
# 3        0.10  10.47  112.20     0.20     6.72    0.10  226.952556       Poor
# 4        0.10   9.12  106.35     0.20     5.75    0.08  226.952556       Poor
# ...       ...    ...     ...      ...      ...     ...         ...        ...
# 1048570  0.09   1.00    9.90     0.10     0.90    0.00  297.000000       Poor
# 1048571  0.10   1.00    9.90     0.10     0.90    0.00  290.000000       Poor
# 1048572  0.11   1.00    9.90     0.10     0.90    0.00  283.000000       Poor
# 1048573  0.20   0.63  120.53     0.80     0.90    0.00  272.000000       Poor
# 1048574  0.35   2.41  102.49     0.34     0.61    0.00  259.000000       Poor
#
# [1048575 rows x 16 columns]

# %% [markdown]
# ### Now we can see all missing values are filled with 'ffill' method

# %% [markdown]
# ## Now we can see all data set all clean and not having any missing values

# %% [markdown]
# <!-- ## Visual Representation of AQI over the year -->

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Finding the correlation between features and Target values

# %% [markdown]
# ### Here are some graphical representation of correlation between features and target index

# %% [markdown]
# ### correlation heatmap

# %%
plt.figure(figsize = (12,10))
sns.heatmap(city_day.corr(), cmap = 'coolwarm', annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.regplot(x = 'PM2.5', y = 'AQI',data=city_day)
# Out:
# <AxesSubplot:xlabel='PM2.5', ylabel='AQI'>

# %%
sns.regplot(x = 'PM10', y = 'AQI',data=city_day)
# Out:
# <AxesSubplot:xlabel='PM10', ylabel='AQI'>

# %%
sns.regplot(x = 'NO', y = 'AQI',data=city_day)
# Out:
# <AxesSubplot:xlabel='NO', ylabel='AQI'>

# %%
sns.regplot(x = 'NO2', y = 'AQI',data=city_day)
# Out:
# <AxesSubplot:xlabel='NO2', ylabel='AQI'>

# %%
sns.regplot(x = 'NOx', y = 'AQI',data=city_day)
# Out:
# <AxesSubplot:xlabel='NOx', ylabel='AQI'>

# %%
sns.regplot(x = 'NH3', y = 'AQI',data=city_day)
# Out:
# <AxesSubplot:xlabel='NH3', ylabel='AQI'>

# %%
sns.regplot(x = 'CO', y = 'AQI',data=city_day)
# Out:
# <AxesSubplot:xlabel='CO', ylabel='AQI'>

# %%
sns.regplot(x = 'SO2', y = 'AQI',data=city_day)
# Out:
# <AxesSubplot:xlabel='SO2', ylabel='AQI'>

# %%
sns.regplot(x = 'O3', y = 'AQI',data=city_day)
# Out:
# <AxesSubplot:xlabel='O3', ylabel='AQI'>

# %%
sns.regplot(x = 'Benzene', y = 'AQI',data=city_day)
# Out:
# <AxesSubplot:xlabel='Benzene', ylabel='AQI'>

# %%
sns.regplot(x = 'Toluene', y = 'AQI',data=city_day)
# Out:
# <AxesSubplot:xlabel='Toluene', ylabel='AQI'>

# %%
sns.regplot(x = 'Xylene', y = 'AQI',data=city_day)
# Out:
# <AxesSubplot:xlabel='Xylene', ylabel='AQI'>

# %%
city_day.corr()
# Out:
#             PM2.5      PM10        NO       NO2       NOx       NH3        CO  \
# PM2.5    1.000000  0.343039  0.358803  0.336790  0.276202  0.106241  0.107399
# PM10     0.343039  1.000000  0.352236  0.301294  0.264048  0.114098  0.039597
# NO       0.358803  0.352236  1.000000  0.421061  0.612566  0.110337  0.194540
# NO2      0.336790  0.301294  0.421061  1.000000  0.489647  0.127497  0.353373
# NOx      0.276202  0.264048  0.612566  0.489647  1.000000  0.049603  0.184152
# NH3      0.106241  0.114098  0.110337  0.127497  0.049603  1.000000  0.009252
# CO       0.107399  0.039597  0.194540  0.353373  0.184152  0.009252  1.000000
# SO2      0.135227  0.157709  0.133410  0.283950  0.106738 -0.048139  0.430839
# O3       0.166912  0.153122  0.028060  0.286503  0.109912  0.074319  0.043637
# Benzene  0.026844  0.031565  0.026581  0.040492  0.023654  0.005675  0.066817
# Toluene  0.128331  0.112930  0.126067  0.305538  0.142145  0.043274  0.286003
# Xylene  -0.028994  0.024869  0.019073  0.102112 -0.020897 -0.010838  0.115370
# AQI      0.587662  0.325366  0.394081  0.509164  0.381926  0.064580  0.639287
#
#               SO2        O3   Benzene   Toluene    Xylene       AQI
# PM2.5    0.135227  0.166912  0.026844  0.128331 -0.028994  0.587662
# PM10     0.157709  0.153122  0.031565  0.112930  0.024869  0.325366
# NO       0.133410  0.028060  0.026581  0.126067  0.019073  0.394081
# NO2      0.283950  0.286503  0.040492  0.305538  0.102112  0.509164
# NOx      0.106738  0.109912  0.023654  0.142145 -0.020897  0.381926
# NH3     -0.048139  0.074319  0.005675  0.043274 -0.010838  0.064580
# CO       0.430839  0.043637  0.066817  0.286003  0.115370  0.639287
# SO2      1.000000  0.136523  0.013145  0.195815  0.088904  0.385953
# O3       0.136523  1.000000  0.026777  0.146520  0.062756  0.185185
# Benzene  0.013145  0.026777  1.000000  0.632012  0.084402  0.042987
# Toluene  0.195815  0.146520  0.632012  1.000000  0.192025  0.275015
# Xylene   0.088904  0.062756  0.084402  0.192025  1.000000  0.044791
# AQI      0.385953  0.185185  0.042987  0.275015  0.044791  1.000000

# %% [markdown]
# ### We can't remove any feature from data set because we have to divide these features in vehical pollutants and industrial pollutants

# %% [markdown]
# # Analysis of Some vehicle and industrial pollutants

# %% [markdown]
# ### As we are only taking 2020

# %%
# data for 2020
city_day2=city_day[city_day['Date'] >= ('2020-01-01')]
print(city_day.shape)
city_day2.head()
# Out:
# (29531, 16)
#            City        Date  PM2.5    PM10    NO    NO2    NOx      NH3    CO  \
# 1826  Ahmedabad  2020-01-01  79.57  131.62  3.78  12.64   8.99  22.3594  3.78
# 1827  Ahmedabad  2020-01-02  72.59  128.86  3.63  14.38   9.73  22.3594  3.63
# 1828  Ahmedabad  2020-01-03  69.54  128.99  7.06  15.13  12.65  22.3594  7.06
# 1829  Ahmedabad  2020-01-04  66.20  138.47  8.97  20.79  16.84  22.3594  8.97
# 1830  Ahmedabad  2020-01-05  55.99  110.41  5.41  15.34  11.53  22.3594  5.41
#
#         SO2     O3  Benzene  Toluene  Xylene    AQI AQI_Bucket
# 1826  27.70  23.67     4.21    31.42    2.52  216.0       Poor
# 1827  23.96  23.67     3.71    31.14    2.52  162.0   Moderate
# 1828  35.78  23.66     4.78    31.14    2.52  220.0       Poor
# 1829  38.98  23.65     4.12    31.14    2.52  254.0       Poor
# 1830  45.83  23.61     3.30    31.14    2.52  255.0       Poor

# %% [markdown]
# #### AS INDEX IS MIXED WE NEED TO FIX THE INDEX

# %%
city_day2.reset_index(drop=True,inplace=True)
city_day.head()
# Out:
#         City        Date      PM2.5      PM10     NO    NO2    NOx      NH3  \
# 0  Ahmedabad  2015-01-01  66.130899  95.07043   0.92  18.22  17.15  22.3594
# 1  Ahmedabad  2015-01-02  66.130899  95.07043   0.97  15.69  16.46  22.3594
# 2  Ahmedabad  2015-01-03  66.130899  95.07043  17.40  19.30  29.70  22.3594
# 3  Ahmedabad  2015-01-04  66.130899  95.07043   1.70  18.48  17.97  22.3594
# 4  Ahmedabad  2015-01-05  66.130899  95.07043  22.10  21.42  37.76  22.3594
#
#       CO    SO2      O3  Benzene  Toluene  Xylene         AQI AQI_Bucket
# 0   0.92  27.64  133.36     0.00     0.02    0.00  166.463581   Moderate
# 1   0.97  24.55   34.06     3.68     5.50    3.77  166.463581   Moderate
# 2  17.40  29.07   30.70     6.80    16.40    2.25  166.463581   Moderate
# 3   1.70  18.59   36.08     4.43    10.14    1.00  166.463581   Moderate
# 4  22.10  39.33   39.31     7.01    18.89    2.78  166.463581   Moderate

# %% [markdown]
# ### how much is the average amount of pollution in each city stations

# %%
most_polluted = city_day2[['City', 'AQI', 'PM10', 'CO']].groupby(['City']).mean().sort_values(by = 'AQI', ascending = False)
most_polluted
# Out:
#                            AQI        PM10        CO
# City
# Ahmedabad           239.176203  107.602514  8.823169
# Delhi               181.672131  157.034208  1.057760
# Patna               162.251366  123.660984  1.133333
# Talcher             161.543807  113.696339  1.690055
# Guwahati            161.508197  126.922186  0.774590
# Gurugram            158.655738  134.434754  1.126885
# Lucknow             157.125683   31.580000  1.196995
# Jorapokhar          147.763580  134.516667  1.299836
# Brajrajnagar        147.053235  146.442240  0.484754
# Bhopal              117.577245  101.083880  0.682568
# Kolkata             117.295082   94.280219  0.643005
# Kochi               105.820088   67.335432  1.296667
# Jaipur              105.120219   97.434044  0.771421
# Mumbai              103.568306   94.733661  0.626776
# Amritsar             96.591105   90.288415  0.686503
# Ernakulam            96.476372   48.180309  1.631049
# Visakhapatnam        86.919770   82.634372  0.628852
# Coimbatore           82.696812   37.544262  0.648087
# Shillong             82.245939   41.050383  0.223880
# Chennai              80.251366   97.950929  0.820710
# Bengaluru            79.715847   67.031639  0.871311
# Hyderabad            78.174863   77.971585  0.464645
# Chandigarh           71.915102   67.242568  0.552295
# Thiruvananthapuram   66.464481   51.330000  0.747104
# Amaravati            59.879781   50.295246  0.420109
# Aizawl               37.096701   23.200973  0.283628

# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn-whitegrid')
f, ax_ = plt.subplots(1, 3, figsize = (15,15))

bar1 = sns.barplot(x = most_polluted.AQI,
                   y = most_polluted.index,
                   palette = 'Reds_r',
                   ax = ax_[0]);

bar1 = sns.barplot(x = most_polluted.PM10,
                   y = most_polluted.index,
                   palette = 'RdBu',
                   ax = ax_[1]);

bar1 = sns.barplot(x = most_polluted.CO,
                   y = most_polluted.index,
                   palette = 'RdBu',
                   ax = ax_[2]);

titles = ['AirQualityIndex', 'ParticulateMatter10', 'CO']
for i in range(3) :
    ax_[i].set_ylabel('')   
    ax_[i].set_yticklabels(labels = ax_[i].get_yticklabels(),fontsize = 14);
    ax_[i].set_title(titles[i])
    f.tight_layout()

# %% [markdown]
# AS THERE ARE MANY POLUTANTS IN THE AIR WE ARE CLASSIFYING THEM INTO 2 CATEGORIES
#
# VEHICLE_POLUTANTS : PM2.5 , PM10 , NO , NOx , NH3 , CO
#
# INDUSTRY_POLUTANT : SO2 , O3 , BENZENE , TOLUENE , XYLENE

# %%
df1=city_day2.copy()
df1['Vehicle_Pollution_content']=df1['PM2.5']+df1['PM10']+df1['NO']+df1['NOx']+df1['NH3']+df1['CO']
df1['Industry_pollutants']=df1['SO2']+df1['O3']+df1['Benzene']+df1['Toluene']+df1['Xylene']
df1.drop(['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene'],axis=1,inplace=True)
df1.head()
# Out:
#         City        Date    AQI AQI_Bucket  Vehicle_Pollution_content  \
# 0  Ahmedabad  2020-01-01  216.0       Poor                   250.0994
# 1  Ahmedabad  2020-01-02  162.0   Moderate                   240.7994
# 2  Ahmedabad  2020-01-03  220.0       Poor                   247.6594
# 3  Ahmedabad  2020-01-04  254.0       Poor                   261.8094
# 4  Ahmedabad  2020-01-05  255.0       Poor                   211.1094
#
#    Industry_pollutants
# 0                89.52
# 1                85.00
# 2                97.88
# 3               100.41
# 4               106.40

# %% [markdown]
# #### DISTRIBUTING DATE INTO DAY AND MONTH COLUMNS

# %%
df1['Day_date']=pd.to_datetime(df1['Date'],format='%Y/%m/%d').dt.day
df1['month_date']=pd.to_datetime(df1['Date'],format='%Y/%m/%d').dt.month
df1['year'] = pd.DatetimeIndex(df1['Date']).year
df1.head()
# Out:
#         City        Date    AQI AQI_Bucket  Vehicle_Pollution_content  \
# 0  Ahmedabad  2020-01-01  216.0       Poor                   250.0994
# 1  Ahmedabad  2020-01-02  162.0   Moderate                   240.7994
# 2  Ahmedabad  2020-01-03  220.0       Poor                   247.6594
# 3  Ahmedabad  2020-01-04  254.0       Poor                   261.8094
# 4  Ahmedabad  2020-01-05  255.0       Poor                   211.1094
#
#    Industry_pollutants  Day_date  month_date  year
# 0                89.52         1           1  2020
# 1                85.00         2           1  2020
# 2                97.88         3           1  2020
# 3               100.41         4           1  2020
# 4               106.40         5           1  2020

# %%
df1.describe()
# Out:
#                AQI  Vehicle_Pollution_content  Industry_pollutants  \
# count  4646.000000                4646.000000          4646.000000
# mean    116.084655                 198.278782            61.598087
# std      82.194488                 132.625765            64.845290
# min      14.000000                  11.420000             4.830000
# 25%      67.000000                 108.317500            37.840000
# 50%      96.000000                 160.375000            51.985000
# 75%     142.000000                 248.732500            72.020000
# max    1291.000000                1160.540000           970.560000
#
#           Day_date   month_date    year
# count  4646.000000  4646.000000  4646.0
# mean     15.659923     3.569307  2020.0
# std       8.818621     1.710550     0.0
# min       1.000000     1.000000  2020.0
# 25%       8.000000     2.000000  2020.0
# 50%      16.000000     4.000000  2020.0
# 75%      23.000000     5.000000  2020.0
# max      31.000000     7.000000  2020.0

# %% [markdown]
# #### IDENTIFYING OUTLIERS

# %%
outliers=df1.loc[df1['Vehicle_Pollution_content'] > (1000)]
outliers
# Out:
#               City        Date         AQI AQI_Bucket  \
# 1159  Brajrajnagar  2020-05-11  166.463581   Moderate
# 1160  Brajrajnagar  2020-05-12  166.463581   Moderate
# 1162  Brajrajnagar  2020-05-14  178.000000   Moderate
# 1760         Delhi  2020-01-01  492.000000     Severe
# 1761         Delhi  2020-01-02  485.000000     Severe
# 2302      Guwahati  2020-01-15  462.000000     Severe
#
#       Vehicle_Pollution_content  Industry_pollutants  Day_date  month_date  \
# 1159                    1031.71                61.02        11           5
# 1160                    1025.09                66.02        12           5
# 1162                    1010.67               102.24        14           5
# 1760                    1160.54               128.74         1           1
# 1761                    1092.40               141.57         2           1
# 2302                    1154.02                43.26        15           1
#
#       year
# 1159  2020
# 1160  2020
# 1162  2020
# 1760  2020
# 1761  2020
# 2302  2020

# %%
outliers=df1.loc[df1['Industry_pollutants']>(800)]
outliers
# Out:
#           City        Date   AQI    AQI_Bucket  Vehicle_Pollution_content  \
# 3938  Shillong  2020-01-25  68.0  Satisfactory                     102.99
# 3939  Shillong  2020-01-26  74.0  Satisfactory                     105.60
# 3971  Shillong  2020-02-27  60.0  Satisfactory                      50.26
# 3972  Shillong  2020-02-28  42.0          Good                      46.68
# 3973  Shillong  2020-02-29  51.0  Satisfactory                      49.98
# 3974  Shillong  2020-03-01  53.0  Satisfactory                      69.49
# 3975  Shillong  2020-03-02  60.0  Satisfactory                      88.69
# 3976  Shillong  2020-03-03  63.0  Satisfactory                      71.86
# 3977  Shillong  2020-03-04  64.0  Satisfactory                      90.79
# 3978  Shillong  2020-03-05  63.0  Satisfactory                      65.67
# 3979  Shillong  2020-03-06  64.0  Satisfactory                      68.64
# 3980  Shillong  2020-03-07  65.0  Satisfactory                      67.12
# 3981  Shillong  2020-03-08  73.0  Satisfactory                      61.44
# 3982  Shillong  2020-03-09  65.0  Satisfactory                      76.82
# 3983  Shillong  2020-03-10  71.0  Satisfactory                     105.45
# 3984  Shillong  2020-03-11  66.0  Satisfactory                      67.77
# 3985  Shillong  2020-03-12  56.0  Satisfactory                      81.46
# 3986  Shillong  2020-03-13  59.0  Satisfactory                      99.15
# 3987  Shillong  2020-03-14  86.0  Satisfactory                     134.39
# 3988  Shillong  2020-03-15  77.0  Satisfactory                      73.96
#
#       Industry_pollutants  Day_date  month_date  year
# 3938               909.72        25           1  2020
# 3939               924.80        26           1  2020
# 3971               847.87        27           2  2020
# 3972               841.15        28           2  2020
# 3973               943.41        29           2  2020
# 3974               908.04         1           3  2020
# 3975               916.14         2           3  2020
# 3976               915.21         3           3  2020
# 3977               946.55         4           3  2020
# 3978               917.84         5           3  2020
# 3979               968.07         6           3  2020
# 3980               892.62         7           3  2020
# 3981               901.51         8           3  2020
# 3982               945.90         9           3  2020
# 3983               970.56        10           3  2020
# 3984               959.25        11           3  2020
# 3985               909.40        12           3  2020
# 3986               904.25        13           3  2020
# 3987               918.38        14           3  2020
# 3988               922.96        15           3  2020

# %%
sns.pairplot(data=df1)

# %%
df1
# Out:
#                City        Date    AQI    AQI_Bucket  \
# 0         Ahmedabad  2020-01-01  216.0          Poor
# 1         Ahmedabad  2020-01-02  162.0      Moderate
# 2         Ahmedabad  2020-01-03  220.0          Poor
# 3         Ahmedabad  2020-01-04  254.0          Poor
# 4         Ahmedabad  2020-01-05  255.0          Poor
# ...             ...         ...    ...           ...
# 4641  Visakhapatnam  2020-06-27   41.0          Good
# 4642  Visakhapatnam  2020-06-28   70.0  Satisfactory
# 4643  Visakhapatnam  2020-06-29   68.0  Satisfactory
# 4644  Visakhapatnam  2020-06-30   54.0  Satisfactory
# 4645  Visakhapatnam  2020-07-01   50.0          Good
#
#       Vehicle_Pollution_content  Industry_pollutants  Day_date  month_date  \
# 0                      250.0994                89.52         1           1
# 1                      240.7994                85.00         2           1
# 2                      247.6594                97.88         3           1
# 3                      261.8094               100.41         4           1
# 4                      211.1094               106.40         5           1
# ...                         ...                  ...       ...         ...
# 4641                   106.1200                46.89        27           6
# 4642                   130.9300                46.19        28           6
# 4643                   121.6100                39.40        29           6
# 4644                   100.0100                38.14        30           6
# 4645                   101.2400                19.15         1           7
#
#       year
# 0     2020
# 1     2020
# 2     2020
# 3     2020
# 4     2020
# ...    ...
# 4641  2020
# 4642  2020
# 4643  2020
# 4644  2020
# 4645  2020
#
# [4646 rows x 9 columns]

# %% [markdown]
# ## Vehical Pollutants vs Industrial Poullutants over 2015 - 2022

# %%
df2=city_day.copy()
df2['Vehicle_Pollution_content']=df2['PM2.5']+df2['PM10']+df2['NO']+df2['NOx']+df2['NH3']+df2['CO']
df2['Industry_pollutants']=df2['SO2']+df2['O3']+df2['Benzene']+df2['Toluene']+df2['Xylene']
df2.drop(['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene'],axis=1,inplace=True)
df2.head()
# Out:
#         City        Date         AQI AQI_Bucket  Vehicle_Pollution_content  \
# 0  Ahmedabad  2015-01-01  166.463581   Moderate                 202.550729
# 1  Ahmedabad  2015-01-02  166.463581   Moderate                 201.960729
# 2  Ahmedabad  2015-01-03  166.463581   Moderate                 248.060729
# 3  Ahmedabad  2015-01-04  166.463581   Moderate                 204.930729
# 4  Ahmedabad  2015-01-05  166.463581   Moderate                 265.520729
#
#    Industry_pollutants
# 0               161.02
# 1                71.56
# 2                85.22
# 3                70.24
# 4               107.32

# %%
## Convert into datetime
df2['Date'] = pd.to_datetime(df2['Date'])
df2['Year'] = df2['Date'].dt.year
df2.head()
# Out:
#         City       Date         AQI AQI_Bucket  Vehicle_Pollution_content  \
# 0  Ahmedabad 2015-01-01  166.463581   Moderate                 202.550729
# 1  Ahmedabad 2015-01-02  166.463581   Moderate                 201.960729
# 2  Ahmedabad 2015-01-03  166.463581   Moderate                 248.060729
# 3  Ahmedabad 2015-01-04  166.463581   Moderate                 204.930729
# 4  Ahmedabad 2015-01-05  166.463581   Moderate                 265.520729
#
#    Industry_pollutants  Year
# 0               161.02  2015
# 1                71.56  2015
# 2                85.22  2015
# 3                70.24  2015
# 4               107.32  2015

# %% [markdown]
# ### Vehical Pollutants over 2015-2020

# %%
data2 = df2[(df2['City'] == 'Mumbai') | (df2['City'] == 'Delhi') | (df2['City'] == 'Bengaluru') | (df2['City'] == 'Ahmedabad') | (df2['City'] == 'Chennai')]
plt.title('Industry_pollutants Levels of some metro cities 2015-2020')
sns.lineplot(x='Year',y='Vehicle_Pollution_content', data=data2, hue='City');

# %% [markdown]
# ### Industrial Pollutants over 2015-2020

# %%
data2 = df2[(df2['City'] == 'Mumbai') | (df2['City'] == 'Delhi') | (df2['City'] == 'Bengaluru') | (df2['City'] == 'Ahmedabad') | (df2['City'] == 'Chennai')]
plt.title('Vehicle_Pollution Levels of some metro cities 2015-2020')
sns.lineplot(x='Year',y='Industry_pollutants', data=data2, hue='City');

# %% [markdown]
# # Model Selection

# %%
city_day.head(2)
# Out:
#         City        Date      PM2.5      PM10    NO    NO2    NOx      NH3  \
# 0  Ahmedabad  2015-01-01  66.130899  95.07043  0.92  18.22  17.15  22.3594
# 1  Ahmedabad  2015-01-02  66.130899  95.07043  0.97  15.69  16.46  22.3594
#
#      CO    SO2      O3  Benzene  Toluene  Xylene         AQI AQI_Bucket
# 0  0.92  27.64  133.36     0.00     0.02    0.00  166.463581   Moderate
# 1  0.97  24.55   34.06     3.68     5.50    3.77  166.463581   Moderate

# %%
df_target = city_day['AQI']
df_features = city_day[['PM2.5','PM10','NO','NO2','NOx','NH3','CO','O3','Benzene','Toluene','Xylene']]

# %% [markdown]
# ### for training and test we have to split the featrues and target values in training and testing part

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(df_features,df_target,test_size = 0.3)   # 30% set are test samplt and 70% are train sample

# %%
x_train.shape
# Out:
# (20671, 11)

# %%
x_test.shape
# Out:
# (8860, 11)

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()

# %%
clf.fit(x_train,y_train)   #for training the model
# Out:
# LinearRegression()

# %%
clf.predict(x_test)   # this line of code will give the AQI value(predicted), we can compare this with y_test
# Out:
# array([167.96511954, 189.49406116,  93.89152222, ..., 346.39302986,
#        336.99080058, 240.22852919])

# %%
y_test
# Out:
# 18644    170.000000
# 26478    166.463581
# 4833     143.000000
# 26285    166.463581
# 21417    230.000000
#             ...
# 13053    131.000000
# 5641      64.000000
# 24770    398.000000
# 19251    346.000000
# 11417    239.000000
# Name: AQI, Length: 8860, dtype: float64

# %%
clf.score(x_test,y_test)
# Out:
# 0.7479025896441905

# %%
clf.predict([[49.3,140,27,22,46,13,12,6,21,13,2]])
## 'PM2.5','PM10','NO','NO2','NOx','NH3','CO','O3','Benzene','Toluene','Xylene'
# Out:
# array([252.90131605])
